# %% [markdown]
# <a href="https://colab.research.google.com/github/Serenahd/low-code-AI-book/blob/Assistant/Serena13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# !pip install python-docx nltk

# %%
def read_word_file(file_path):
    doc = docx.Document(file_path)
    text = "\n".join([para.text for para in doc.paragraphs if para.text.strip()])  # Remove empty lines
    return text

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6fbe0804-bd1b-4877-bf63-a16d38b4692d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fbe0804-bd1b-4877-bf63-a16d38b4692d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = "/content/Attraction summer.docx"  # Update with actual filename
text_data = read_word_file(file_path)

# %%
print(text_data[:500])
# Out:
# Batroun:
# Local Attractions:
# Type: Free of charge
# St. Stephan's Cathedral
# Map Location: 7M45+RFX 1400
# Port (facing the Cathedral)
# Church of our lady of the sea
# Map location: https://www.google.com/maps/dir//7M34%2BWC4,+Lebanon/@34.2547438,35.5736657,12z/data=!4m8!4m7!1m0!1m5!1m1!1s0x151f58a58b39aaad:0xb1c38d0bc931c795!2m2!1d35.6560669!2d34.2547714?entry=ttu&g_ep=EgoyMDI1MDExNS4wIKXMDSoASAFQAw%3D%3D
# Phoenician wall
# Batroun Old souks
# Diaspora village
# Wishing well
# Winery window experience-

# %%
import re

# %%
def clean_text(text):
    text = re.sub(r"(https?://\S+)", " ", text)  # Replace URLs with a space
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"\n+", " ", text)  # Remove extra newlines
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # Remove special characters
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# %%
cleaned_text = clean_text(text_data)

# %%
print(cleaned_text[:500])
# Out:
# batroun local attractions type free of charge st stephans cathedral map location 7m45rfx 1400 port facing the cathedral church of our lady of the sea map location phoenician wall batroun old souks diaspora village wishing well winery window experiencepriced per glass bahsa beachentrance free of charge unless you rent a parasol andor beach chair nature hikes free of charge experience no guide needed nahr el jawzbeit chlela trail location bayt chlela around 25 km40 minutes from batroun old souks b

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download("punkt_tab")
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)  # Tokenization
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    return " ".join(filtered_tokens)

# %%
preprocessed_text = preprocess_text(cleaned_text)

# %%
print(preprocessed_text[:500])
# Out:
# batroun local attractions type free charge st stephans cathedral map location 7m45rfx 1400 port facing cathedral church lady sea map location phoenician wall batroun old souks diaspora village wishing well winery window experiencepriced per glass bahsa beachentrance free charge unless rent parasol andor beach chair nature hikes free charge experience guide needed nahr el jawzbeit chlela trail location bayt chlela around 25 km40 minutes batroun old souks car map location mussaylha fort location h

# %%
with open("processed_text.txt", "w", encoding="utf-8") as f:
    f.write(preprocessed_text)

# %%
from google.colab import files
files.download("processed_text.txt")  # Download file

# %%
# !pip install python-docx nltk

# %%
def read_word_file(file_path):
    doc = docx.Document(file_path)
    text = "\n".join([para.text for para in doc.paragraphs if para.text.strip()])  # Remove empty lines
    return text

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4fc6bec2-c09b-4cc5-be21-bc8e2664122c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4fc6bec2-c09b-4cc5-be21-bc8e2664122c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = "/content/Attraction winter.docx"  # Update with actual filename
text_data = read_word_file(file_path)

# %%
print(text_data[:500])
# Out:
# Mzaar ski resort
# Website: https://www.mzaarskiresort.com/
# Map location: https://www.google.com/maps/dir/45.4623232,9.2045312/map+location+of+mzaar+ski+resort/@39.5199253,12.152361,5z/data=!3m1!4b1!4m9!4m8!1m1!4e1!1m5!1m1!1s0x151f4c163dc8741b:0xd841e25cb8936d2e!2m2!1d35.8432747!2d33.9927724?entry=ttu&g_ep=EgoyMDI1MDEyMS4wIKXMDSoASAFQAw%3D%3D
# Ski & Snowboard
#   Adults
# Kids
# Cross country skiing
# Enjoy a physical and revitalizing experience on the different circuits starting from the button of r

# %%
import re

# %%
def clean_text(text):
    text = re.sub(r"(https?://\S+)", " ", text)  # Replace URLs with a space
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"\n+", " ", text)  # Remove extra newlines
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # Remove special characters
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# %%
cleaned_text = clean_text(text_data)

# %%
print(cleaned_text[:500])
# Out:
# mzaar ski resort website map location ski snowboard adults kids cross country skiing enjoy a physical and revitalizing experience on the different circuits starting from the button of refuge to the top of mzaar raquette discover the mountain through a workout against a peaceful magical backdrop available to rent from at intercontinental store rental level snowmobile looking for an escape and some thrills you can try our snowmobiles and discover a different side of the mountains warde main road z

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download("punkt_tab")
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)  # Tokenization
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    return " ".join(filtered_tokens)

# %%
preprocessed_text = preprocess_text(cleaned_text)

# %%
print(preprocessed_text[:500])
# Out:
# mzaar ski resort website map location ski snowboard adults kids cross country skiing enjoy physical revitalizing experience different circuits starting button refuge top mzaar raquette discover mountain workout peaceful magical backdrop available rent intercontinental store rental level snowmobile looking escape thrills try snowmobiles discover different side mountains warde main road zipline feel like fly speeds 2025 mph lines 50 feet air 780 feet length adventure begins top mountain routes tre

# %%
with open("processed_text.txt", "w", encoding="utf-8") as f:
    f.write(preprocessed_text)

# %%
from google.colab import files
files.download("processed_text.txt")  # Download file

# %%
# !pip install python-docx nltk

# %%
def read_word_file(file_path):
    doc = docx.Document(file_path)
    text = "\n".join([para.text for para in doc.paragraphs if para.text.strip()])  # Remove empty lines
    return text

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1e5fd1e-896b-43a1-998d-48f63db92c08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1e5fd1e-896b-43a1-998d-48f63db92c08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = "/content/faraya-summer attraction.docx"  # Update with actual filename
text_data = read_word_file(file_path)

# %%
print(text_data[:500])
# Out:
# Local Attractions:
# Type: Free of charge
# Faraya Waterfall
# Faqra Natural Bridge
# Hike to the largest high cross
# Visit Saint Charbel statue and chapel
# Go for a walk around Chabrouh Dam
# Jabal Moussa biosphere reserve (small entrance fee)
# Guides are optional and chargeable for all the trails
# Traditional activities are available as well (chargeable)
# Visit the shop -
# https://www.jabalmoussa.org/trails-facilities#
# Walk to visit Saydit l darjeh (small church on the top of the mountain)
# Authenti

# %%
import re

# %%
def clean_text(text):
    text = re.sub(r"(https?://\S+)", " ", text)  # Replace URLs with a space
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"\n+", " ", text)  # Remove extra newlines
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # Remove special characters
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# %%
cleaned_text = clean_text(text_data)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download("punkt_tab")
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)  # Tokenization
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    return " ".join(filtered_tokens)

# %%
preprocessed_text = preprocess_text(cleaned_text)

# %%
print(preprocessed_text[:500])
# Out:
# local attractions type free charge faraya waterfall faqra natural bridge hike largest high cross visit saint charbel statue chapel go walk around chabrouh dam jabal moussa biosphere reserve small entrance fee guides optional chargeable trails traditional activities available well chargeable visit shop walk visit saydit l darjeh small church top mountain authentic wine tasting visit vignoble joura faqra ruins small entrance fee kfardebian hiking trail ahlam golf mountain village type guided tours

# %%
with open("processed_text.txt", "w", encoding="utf-8") as f:
    f.write(preprocessed_text)

# %%
from google.colab import files
files.download("processed_text.txt")  # Download file
